# %% [raw]
# %load_ext autoreload
# %autoreload 2

# %%
# !git clone
# Out:
# Cloning into 'hifi-gan'...
# remote: Enumerating objects: 162, done.
# remote: Counting objects: 100% (162/162), done.
# remote: Compressing objects: 100% (120/120), done.
# remote: Total 162 (delta 64), reused 128 (delta 33), pack-reused 0
# Receiving objects: 100% (162/162), 1.89 MiB | 10.93 MiB/s, done.
# Resolving deltas: 100% (64/64), done.

# %%
import os

os.environ['WANDB_API_KEY'] = ''

# %%
# !pip install speechbrain
# Out:
# ...
#   Obtaining dependency information for speechbrain from https://files.pythonhosted.org/packages/30/ff/9629de25786cf6ce38b7754b352a9904ce8c90b22a127d9d0d9c45ef5693/speechbrain-0.5.16-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for hyperpyyaml from https://files.pythonhosted.org/packages/33/c9/751b6401887f4b50f9307cc1e53d287b3dc77c375c126aeb6335aff73ccb/HyperPyYAML-1.2.2-py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 630.6/630.6 kB 12.3 MB/s eta 0:00:00a 0:00:01
# ...

# %%
# !cd hifi-gan; python train.py --config /kaggle/working/hifi-gan/src/configs/hifi-gan.json
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# ...
# Loading LJSpeech
# ...
# LJSpeech-1.1.tar.bz2: 2.75GB [00:59, 46.0MB/s]
# Preparing ljspeech folders: train: 100%|██████████| 1/1 [00:01<00:00,  1.67s/it]
# wandb: Currently logged in as: dzhunkoffski. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.0
# wandb: Run data is saved locally in /kaggle/working/hifi-gan/wandb/run-20231204_095201-au7lk4wf
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run gentle-field-45
# wandb: ⭐️ View project at https://wandb.ai/dzhunkoffski/hifigan
# wandb: 🚀 View run at https://wandb.ai/dzhunkoffski/hifigan/runs/au7lk4wf
# /kaggle/input/hifigan-checkpoint/checkpoint-epoch30.pth
# go resume
# ...
